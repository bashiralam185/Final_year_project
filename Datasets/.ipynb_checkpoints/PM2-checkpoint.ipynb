# %%
# importing pands
import pandas as pd


# reading dataset
data = pd.read_csv("PM2/Bishkek_PM2.5_2022_YTD.csv")

data.tail()
# Out:
#          Site          Parameter            Date (LT)  Year  Month  Day  Hour  \
# 6047  Bishkek  PM2.5 - Principal  2022-09-30 08:00 PM  2022      9   30    20
# 6048  Bishkek  PM2.5 - Principal  2022-09-30 09:00 PM  2022      9   30    21
# 6049  Bishkek  PM2.5 - Principal  2022-09-30 10:00 PM  2022      9   30    22
# 6050  Bishkek  PM2.5 - Principal  2022-09-30 11:00 PM  2022      9   30    23
# 6051  Bishkek  PM2.5 - Principal  2022-10-01 12:00 AM  2022     10    1     0
#
#       NowCast Conc.  AQI AQI Category  Raw Conc. Conc. Unit Duration QC Name
# 6047           28.9   86     Moderate       36.0      UG/M3     1 Hr   Valid
# 6048           31.9   93     Moderate       35.0      UG/M3     1 Hr   Valid
# 6049           29.4   87     Moderate       27.0      UG/M3     1 Hr   Valid
# 6050           29.7   88     Moderate       30.0      UG/M3     1 Hr   Valid
# 6051           31.3   91     Moderate       33.0      UG/M3     1 Hr   Valid

# %%
data1 = pd.read_csv("PM2/Bishkek_PM2.5_2019_YTD.csv")
data2 = pd.read_csv("PM2/Bishkek_PM2.5_2020_12_MTD.csv")
data3 = pd.read_csv("PM2/Bishkek_PM2.5_2020_YTD.csv")
data4 = pd.read_csv("PM2/Bishkek_PM2.5_2021_12_MTD.csv")
data5 = pd.read_csv("PM2/Bishkek_PM2.5_2021_YTD.csv")
data6 = pd.read_csv("PM2/Bishkek_PM2.5_2022_07_MTD.csv")
data7 = pd.read_csv("PM2/Bishkek_PM2.5_2022_10_MTD.csv")
data8 = pd.read_csv("PM2/Bishkek_PM2.5_2022_12_MTD.csv")
data9 = pd.read_csv("PM2/Bishkek_PM2.5_2022_YTD.csv")

# %%
frames = []
def appending(df):
    df["Date (LT)"] = pd.to_datetime(df["Date (LT)"])
    frames.append(df.query("City == 'Bishkek'"))


appending(data1)
appending(data2)
appending(data3)
appending(data4)
appending(data5)
appending(data6)
appending(data7)
appending(data8)
appending(data9)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3799             try:
# -> 3800                 return self._engine.get_loc(casted_key)
#    3801             except KeyError as err:
#
# ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
data["Date (LT)"] = pd.to_datetime(data["Date (LT)"],color)

# %%
# importing plotly
import plotly.express as px

# plotting interactive graphs in Python
fig = px.scatter(data, x="Date (LT)", y="NowCast Conc.", color='AQI Category')
fig.show()
# Out:
# <div>                            <div id="ba220bd1-e415-47ab-8243-0df40d8e6757" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba220bd1-e415-47ab-8243-0df40d8e6757")) {                    Plotly.newPlot(                        "ba220bd1-e415-47ab-8243-0df40d8e6757",                        [{"hovertemplate":"AQI Category=Moderate<br>Date (LT)=%{x}<br>NowCast Conc.=%{y}<extra></extra>","legendgroup":"Moderate","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Moderate","showlegend":true,"x":["2022-01-01T01:00:00","2022-01-01T02:00:00","2022-01-01T03:00:00","2022-01-01T18:00:00","2022-01-02T01:00:00","2022-01-02T02:00:00","2022-01-02T03:00:00","2022-01-02T11:00:00","2022-01-02T12:00:00","2022-01-02T13:00:00","2022-01-02T14:00:00"
# ...

# %%
# importing plotly
import plotly.express as px

# plotting interactive graphs in Python
fig = px.scatter(data, x="Date (LT)", y="AQI", color='AQI Category')
fig.show()
# Out:
# <div>                            <div id="d30f3826-1b0a-4c55-86ce-59aa415ac2d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d30f3826-1b0a-4c55-86ce-59aa415ac2d1")) {                    Plotly.newPlot(                        "d30f3826-1b0a-4c55-86ce-59aa415ac2d1",                        [{"hovertemplate":"AQI Category=Moderate<br>Date (LT)=%{x}<br>AQI=%{y}<extra></extra>","legendgroup":"Moderate","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Moderate","showlegend":true,"x":["2022-01-01T01:00:00","2022-01-01T02:00:00","2022-01-01T03:00:00","2022-01-01T18:00:00","2022-01-02T01:00:00","2022-01-02T02:00:00","2022-01-02T03:00:00","2022-01-02T11:00:00","2022-01-02T12:00:00","2022-01-02T13:00:00","2022-01-02T14:00:00","2022-01-
# ...
