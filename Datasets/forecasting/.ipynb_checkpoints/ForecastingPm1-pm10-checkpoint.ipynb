# %%
import pandas as pd
# reading dataset
data = pd.read_csv("../grid/grid-export.csv")

data.tail()
# Out:
#             Day  PM1(mcg/m³)  PM10(mcg/m³)  PM2.5(mcg/m³)  AQI US  NO(mcg/m³)  \
# 434  2022-08-28         6.20         70.48          16.81   59.52        8.89
# 435  2022-08-29         5.39         66.65          15.50   55.99       28.52
# 436  2022-08-30         5.11         64.76          14.81   54.21        5.69
# 437  2022-08-31         5.58         69.77          15.52   56.70        3.86
# 438  2022-09-01         5.63         71.57          16.26   58.86        4.77
#
#      NO2(mcg/m³)  CH2O(mcg/m³)  SO2(mcg/m³)  Temperature(°C)  Humidity(%)
# 434        27.58           0.0        21.67            24.34        31.41
# 435        34.23           0.0        20.19            23.77        35.32
# 436        30.39           0.0        19.31            23.57        36.31
# 437        27.57           0.0        18.83            24.97        32.14
# 438        28.98           0.0        20.86            25.68        31.01

# %%
data.drop('AQI US', axis=1, inplace=True)
data.drop('NO(mcg/m³)', axis=1, inplace=True)
data.drop('NO2(mcg/m³)', axis=1, inplace=True)
data.drop('CH2O(mcg/m³)', axis=1, inplace=True)
data.drop('SO2(mcg/m³)', axis=1, inplace=True)
data.drop('Temperature(°C)', axis=1, inplace=True)
data.drop('Humidity(%)', axis=1, inplace=True)

# %%
pm1 = data.drop('PM2.5(mcg/m³)', axis=1)
pm1 = pm1.drop('PM10(mcg/m³)', axis=1)

# %%
pm1.head()
# Out:
#           Day  PM1(mcg/m³)
# 0  2021-06-20         6.26
# 1  2021-06-21         5.61
# 2  2021-06-22         6.38
# 3  2021-06-23         6.43
# 4  2021-06-24         5.66

# %%
# python code to rename the columns
pm1.rename(columns={'Day':'ds','PM1(mcg/m³)':'y'},inplace=True)

# %%
# importing python time series packages
from prophet import Prophet

# initialiazing the model with 95% confidence interval
model = Prophet(interval_width= 0.80)

# train model
model.fit(pm1)
# Out:
# 17:15:23 - cmdstanpy - INFO - Chain [1] start processing
# 17:15:23 - cmdstanpy - INFO - Chain [1] done processing

# %%
# forecasting for future
future = model.make_future_dataframe(periods=2, freq='M')

# %%
# forecast predictions
forecast = model.predict(future)

# %%
# visualizing the forecat predictions
fig1 = model.plot(forecast)

# %%
# weekly seasonality and yearly seasonality
fig2 = model.plot_components(forecast)

# %%
pm2 = data.drop('PM1(mcg/m³)', axis=1)
pm2 = pm2.drop('PM10(mcg/m³)', axis=1)

# %%
# python code to rename the columns
pm2.rename(columns={'Day':'ds','PM2.5(mcg/m³)':'y'},inplace=True)

# %%
pm2.head()
# Out:
#            ds      y
# 0  2021-06-20  21.02
# 1  2021-06-21  15.63
# 2  2021-06-22  11.60
# 3  2021-06-23  12.40
# 4  2021-06-24  11.68

# %%
# initialiazing the model with 95% confidence interval
model = Prophet(interval_width= 0.80)

# train model
model.fit(pm2)

# forecasting for future
future = model.make_future_dataframe(periods=2, freq='M')
# forecast predictions
forecast = model.predict(future)
# Out:
# 17:17:16 - cmdstanpy - INFO - Chain [1] start processing
# 17:17:16 - cmdstanpy - INFO - Chain [1] done processing

# %%
# visualizing the forecat predictions
fig1 = model.plot(forecast)

# %%
# weekly seasonality and yearly seasonality
fig2 = model.plot_components(forecast)

# %%
pm10 = data.drop('PM2.5(mcg/m³)', axis=1)
pm10 = pm10.drop('PM1(mcg/m³)', axis=1)

# %%
# python code to rename the columns
pm10.rename(columns={'Day':'ds','PM10(mcg/m³)':'y'},inplace=True)

# %%
# initialiazing the model with 95% confidence interval
model = Prophet(interval_width= 0.80)

# train model
model.fit(pm10)

# forecasting for future
future = model.make_future_dataframe(periods=2, freq='M')
# forecast predictions
forecast = model.predict(future)
# Out:
# 17:22:04 - cmdstanpy - INFO - Chain [1] start processing
# 17:22:04 - cmdstanpy - INFO - Chain [1] done processing

# %%
# visualizing the forecat predictions
fig1 = model.plot(forecast)

# %%
# weekly seasonality and yearly seasonality
fig2 = model.plot_components(forecast)

# %%
# importing dataset
dataset = pd.read_csv('../pm2_data.csv')

dataset.head()
# Out:
#    Unnamed: 0     Site          Parameter            Date (LT)  Year  Month  \
# 0           0  Bishkek  PM2.5 - Principal  2019-02-06 06:00:00  2019      2
# 1           1  Bishkek  PM2.5 - Principal  2019-02-06 07:00:00  2019      2
# 2           2  Bishkek  PM2.5 - Principal  2019-02-06 08:00:00  2019      2
# 3           3  Bishkek  PM2.5 - Principal  2019-02-06 09:00:00  2019      2
# 4           4  Bishkek  PM2.5 - Principal  2019-02-06 10:00:00  2019      2
#
#    Day  Hour  NowCast Conc.  AQI AQI Category  Raw Conc. Conc. Unit Duration  \
# 0    6     6         -999.0 -999          NaN       12.0      UG/M3     1 Hr
# 1    6     7           17.0   61     Moderate       20.0      UG/M3     1 Hr
# 2    6     8           19.1   66     Moderate       21.0      UG/M3     1 Hr
# 3    6     9           22.4   73     Moderate       25.0      UG/M3     1 Hr
# 4    6    10           30.9   91     Moderate       39.0      UG/M3     1 Hr
#
#   QC Name
# 0   Valid
# 1   Valid
# 2   Valid
# 3   Valid
# 4   Valid

# %%
dataset.drop('Unnamed: 0', axis=1, inplace=True)
dataset.drop('Site', axis=1, inplace=True)
dataset.drop('Parameter', axis=1, inplace=True)
dataset.drop('Year', axis=1, inplace=True)
dataset.drop('Month', axis=1, inplace=True)
dataset.drop('Day', axis=1, inplace=True)
dataset.drop('Hour', axis=1, inplace=True)
dataset.drop('NowCast Conc.', axis=1, inplace=True)
dataset.drop('AQI Category', axis=1, inplace=True)
dataset.drop('Raw Conc.', axis=1, inplace=True)
dataset.drop('Conc. Unit', axis=1, inplace=True)
dataset.drop('Duration', axis=1, inplace=True)
dataset.drop('QC Name', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_436712/1664478528.py in <module>
#       7 dataset.drop('Hour', axis=1, inplace=True)
#       8 dataset.drop('NowCast Conc.', axis=1, inplace=True)
# ----> 9 dataset.drop('Hour', axis=1, inplace=True)
#      10 dataset.drop('AQI Category', axis=1, inplace=True)
#      11 dataset.drop('Raw Conc.', axis=1, inplace=True)
#
# ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     315                     stacklevel=find_stack_level(inspect.currentframe()),
#     316                 )
# --> 317             return func(*args, **kwargs)
#     318
#     319         return wrapper
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5389                 weight  1.0     0.8
#    5390         """
# -> 5391         return super().drop(
#    5392             labels=labels,
#    5393             axis=axis,
#
# ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     315                     stacklevel=find_stack_level(inspect.currentframe()),
#     316                 )
# --> 317             return func(*args, **kwargs)
#     318
#     319         return wrapper
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4508         for axis, labels in axes.items():
#    4509             if labels is not None:
# -> 4510                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4511
#    4512         if inplace:
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4549                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4550             else:
# -> 4551                 new_axis = axis.drop(labels, errors=errors)
#    4552             indexer = axis.get_indexer(new_axis)
#    4553
#
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6970         if mask.any():
#    6971             if errors != "ignore":
# -> 6972                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6973             indexer = indexer[~mask]
#    6974         return self.delete(indexer)
#
# KeyError: "['Hour'] not found in axis"
